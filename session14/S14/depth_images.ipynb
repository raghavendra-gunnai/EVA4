# %%
# !cd DenseDepth && dir
# Out:
#  Volume in drive D is Data
#  Volume Serial Number is 2C53-B4F1
#
#  Directory of D:\Projects\theschoolofai\repo\DenseDepth
#
# 02-05-2020  23:05    <DIR>          .
# 02-05-2020  23:05    <DIR>          ..
# 02-05-2020  22:38                60 .gitignore
# 02-05-2020  22:38             9,687 augment.py
# 02-05-2020  22:38             4,031 callbacks.py
# 02-05-2020  22:38             8,113 data.py
# 02-05-2020  22:38            14,807 demo.py
# 02-05-2020  22:38         2,457,728 demo_depth.npy
# 02-05-2020  22:38         7,372,928 demo_rgb.npy
# 02-05-2020  22:38           447,494 DenseDepth.ipynb
# 02-05-2020  22:38             1,627 evaluate.py
# 02-05-2020  22:38    <DIR>          examples
# 02-05-2020  22:38             2,182 layers.py
# 02-05-2020  22:38            35,823 LICENSE
# 02-05-2020  22:38               694 loss.py
# 02-05-2020  22:38             3,154 model.py
# 04-02-2019  11:28       172,897,376 nyu.h5
# 02-05-2020  22:38    <DIR>          PyTorch
# 02-05-2020  22:38             3,786 README.md
# 02-05-2020  22:38    <DIR>          Tensorflow
# 02-05-2020  23:08             1,386 test.py
# 02-05-2020  22:38             4,221 train.py
# 02-05-2020  22:38             5,413 utils.py
# 02-05-2020  22:55    <DIR>          __pycache__
#               18 File(s)    183,270,510 bytes
#                6 Dir(s)  986,311,028,736 bytes free

# %%
#!wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5 -O ./DenseDepth/nyu.h5
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !cd DenseDepth && python test.py
# Out:
# Loading model...
#
# Model loaded (nyu.h5).
#
# Loaded (12) images of size (480, 640, 3).
# Figure(1000x500)
# Using TensorFlow backend.

# %%
from matplotlib import pyplot as plt
from skimage import io

plt.figure(figsize=(20,20))
plt.imshow( io.imread('./DenseDepth/test.png') )

# %%
im = io.imread('./DenseDepth/test.png')

# %%
im.shape
# Out:
# (500, 1000, 4)

# %%
2600/8
# Out:
# 325.0

# %%
320*8
# Out:
# 2560
